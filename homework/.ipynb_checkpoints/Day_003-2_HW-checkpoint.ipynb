# %% [markdown]
# ## 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ### Hints: 使用 [Request](https://blog.gtwang.org/programming/python-requests-module-tutorial/) 抓取資料
# ### Hints: [字串分割](http://www.runoob.com/python/att-string-split.html)
# ### Hints: 例外處理: [Try-Except](https://pydoing.blogspot.com/2011/01/python-try.html)

# %% [markdown]
# # [作業目標]
# - 試著讀取網頁上的圖片連結清單, 再以清單中網址讀取圖片

# %% [markdown]
# # [作業重點]
# - 從網頁上讀取連結清單 (In[1], In[2])
# - 從清單網址讀取圖片 (In[6]~In[9], Out[6]~Out[9])

# %%
## 假如我們不想把資料載到自己的電腦裡?
# 把連結填入
target_url = 'https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt'

# %%
import requests
response = requests.get(target_url)
data_html = response.text

# 用 request 傳送回來的資料不會認得斷行符號
print(len(data_html))
data[0:100]
# Out:
# 784594
# [u'n00015388_157\thttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg',
#  u'n00015388_238\thttp://farm2.static.flickr.com/1005/3352960681_37b9c1d27b.jpg',
#  u'n00015388_304\thttp://farm1.static.flickr.com/27/51009336_a9663af3dd.jpg',
#  u'n00015388_327\thttp://farm4.static.flickr.com/3025/2444687979_bf7bc8df21.jpg',
#  u'n00015388_355\thttp://img100.imageshack.us/img100/3253/forrest004fs9.jpg',
#  u'n00015388_373\thttp://img172.imageshack.us/img172/4606/napo03072en9.jpg',
#  u'n00015388_379\thttp://fotootjesvanannelies.web-log.nl/olifantfotootjes/images/2008/06/04/img_8870.jpg',
#  u'n00015388_388\thttp://www.deweekkrant.nl/images/library/pictures/4f/2e/a5/cf/2_3d81b762a5e8a345bbb1f0884fab2e9762146129.jpg',
#  u'n00015388_442\thttp://www.porschemania.it/discus/messages/815/102099.jpg',
#  u'n00015388_474\thttp://farm1.static.flickr.com/72/225029238_805b0937ca.jpg',
#  u'n00015388_514\thttp://farm2.static.flickr.com/1128/1432436038_6c131f1bb0.jpg',
#  u'n00015388_671\thttp://farm4.static.flickr.com/3217/2942611930_d68204f726.jpg',
#  u'n00015388_686\thttp://farm1.static.flickr.com/29/54608382_ee8bd4f7fa.jpg',
#  u'n00015388_706\thttp://www.dierentuin.nl/images/jongengiraffe.jpg',
#  u'n00015388_725\thttp://farm4.static.flickr.com/3279/3118047175_259ab89c92.jpg',
#  u'n00015388_758\thttps://w3f7yg.bay.livefilestore.com/y1miLTQmcuoRakgVwM6_bngzVE6TzzugspJiu6zK1_8F_kAD0tLiNV6nRNu9gQjci3MNbubrk3M8pSQlHpG3a8NO88Qx4dvvuugxBvdzeYg1j4KQk45GZIrKYpqxRxRMhCWK3PxXknn61E/IMG_4991\u6591\u9a6c.jpg',
#  u'n00015388_841\thttp://farm4.static.flickr.com/3271/2496428562_90b5cb82a6.jpg',
#  u'n00015388_842\thttp://farm2.static.flickr.com/1115/703274169_5ef9b9dfc9.jpg',
#  u'n00015388_1087\thttp://farm1.static.flickr.com/70/200362625_938f8f06a7.jpg',
#  u'n00015388_3833\thttp://homingpidgeon.blog.lastampa.it/il_mio_weblog/images/2009/02/14/koala_cured.jpg',
#  u'n00015388_3871\thttp://farm4.static.flickr.com/3087/2493456165_ecd9e6dcbf.jpg',
#  u'n00015388_3916\thttp://farm3.static.flickr.com/2310/2179327152_9fe4ff499b.jpg',
#  u'n00015388_3970\thttp://farm4.static.flickr.com/3534/3236276663_10af51d4da.jpg',
#  u'n00015388_3984\thttp://farm3.static.flickr.com/2025/1578466713_c30bc5190d.jpg',
#  u'n00015388_4004\thttp://www.theresevangelder.nl/dier8.jpg',
#  u'n00015388_4019\thttp://farm3.static.flickr.com/2341/2410518543_79040ec612.jpg',
#  u'n00015388_4040\thttp://farm1.static.flickr.com/41/99317628_57992c2bf4.jpg',
#  u'n00015388_4044\thttp://kazernediemen.web-log.nl/photos/uncategorized/2008/09/28/img_49141border.jpg',
#  u'n00015388_4067\thttp://www.photophoto.cn/m69/018/026/0180260450.jpg',
#  u'n00015388_4122\thttp://img1.pconline.com.cn/piclib/200804/29/batch/1/1873/1209483781462g460ayo0sr_medium.JPG',
#  u'n00015388_4178\thttp://farm3.static.flickr.com/2246/1862774644_be31884926.jpg',
#  u'n00015388_4214\thttp://www.worldofimages.nl/gallery/dieren/dier-frouke1.jpg',
#  u'n00015388_4221\thttp://estb.msn.com/i/B5/EF99C74EFE7B9DD2FBE2B57AB6B2D.jpg',
#  u'n00015388_4261\thttp://www.yile8.com/Article/UploadFiles/200703/20070326124456286.jpg']

# %%
# 找到換行符號，用該符號做字串分割後，把它拿掉
split_tag = '\n'

data = data_html.split(split_tag)
print(len(data))
data[0]
# Out:
# 9996
# u'n00015388_157\thttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg'

# %%
import pandas as pd
pd.DataFrame([x.split('\t') for x in data], columns=['name', 'link'])

# %% [markdown]
# ## 將 txt 轉成 pandas dataframe

# %%
import pandas as pd

df = pd.DataFrame([x.split('\t') for x in data]) 
df.head()
df[0:5][1].values
# Out:
# array([u'http://farm1.static.flickr.com/145/430300483_21e993670c.jpg',
#        u'http://farm2.static.flickr.com/1005/3352960681_37b9c1d27b.jpg',
#        u'http://farm1.static.flickr.com/27/51009336_a9663af3dd.jpg',
#        u'http://farm4.static.flickr.com/3025/2444687979_bf7bc8df21.jpg',
#        u'http://img100.imageshack.us/img100/3253/forrest004fs9.jpg'], dtype=object)

# %% [markdown]
# ## 讀取圖片，請讀取上面 data frame 中的前 5 張圖片

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

# 請用 df.loc[...] 得到第一筆資料的連結
first_link = df.loc[0][1]

response = requests.get(first_link)
img = Image.open(BytesIO(response.content))

# Convert img to numpy array
# %matplotlib inline
plt.imshow(img)
plt.show()

# %%
def img2arr_fromURLs(url_list, resize = False):
    """
    請完成這個 Function
    Args
        - url_list: list of URLs
        - resize: bool
    Return
        - list of array
    """
    img_list = []
    for url in url_list:
        response = requests.get(url)
        img = Image.open(BytesIO(response.content))
        img_list.append(img)
    return img_list

# %%
result = img2arr_fromURLs(df[0:4][1].values)
print("Total images that we got: %i " % len(result)) # 如果不等於 5, 代表有些連結失效囉

for im_get in result:
    plt.imshow(im_get)
    plt.show()
# Out:
# Total images that we got: 4
